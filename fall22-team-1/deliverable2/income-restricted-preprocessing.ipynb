# %%
import pandas as pd

df = pd.read_csv('../data/income-restricted-inventory-2021.csv', dtype={'Zip Code':str})
df
# Out:
#       Unnamed: 0               Project Name Neighborhood Zip Code  \
# 0              0  Abbot Street/ Shawmut Ave      Roxbury    02119
# 1              1            Academy Homes I      Roxbury    02119
# 2              2           Academy Homes II      Roxbury    02119
# 3              3        Adams Court Phase A     Mattapan    02126
# 4              4        Adams Court Phase B     Mattapan    02126
# ...          ...                        ...          ...      ...
# 1440        1440     xxxxxxxx Blue Hill Ave      Roxbury    02119
# 1441        1441   YouthBuild Ruskindale Rd    Hyde Park    02136
# 1442        1442              YWCA Berkeley    South End    02116
# 1443        1443          YWCA Boston Units     Back Bay    02116
# 1444        1444          Zebra Condominium    South End    02118
#
#       TtlProjUnits  RentUnits  OwnUnits  TtlMarket  MarketRent  MarketOwn  \
# 0               16         16         0        0.0         0.0        0.0
# 1              202        202         0       52.0        52.0        0.0
# 2              236        236         0        0.0         0.0        0.0
# 3               50         50         0        0.0         0.0        0.0
# 4               45         45         0        0.0         0.0        0.0
# ...            ...        ...       ...        ...         ...        ...
# 1440             4          4         0        0.0         0.0        0.0
# 1441             1          0         1        0.0         0.0        0.0
# 1442           208        208         0      168.0       168.0        0.0
# 1443           115        115         0       36.0        36.0        0.0
# 1444            10          7         3        7.0         7.0        0.0
#
#       Total Income-Restricted  Income-Restricted Rental  \
# 0                          16                        16
# 1                         150                       150
# 2                         236                       236
# 3                          50                        50
# 4                          45                        45
# ...                       ...                       ...
# 1440                        4                         4
# 1441                        1                         0
# 1442                       40                        40
# 1443                       79                        79
# 1444                        3                         0
#
#       Income-Restricted Ownership            Tenure Public/ Private  \
# 0                             0.0            Rental         Private
# 1                             0.0            Rental         Private
# 2                             0.0            Rental         Private
# 3                             0.0            Rental         Private
# 4                             0.0            Rental         Private
# ...                           ...               ...             ...
# 1440                          0.0            Rental         Private
# 1441                          1.0         Ownership         Private
# 1442                          0.0            Rental         Private
# 1443                          0.0            Rental         Private
# 1444                          3.0  Ownership/Rental         Private
#
#      Includes Senior Units? Section 8
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                       NaN         Y
# 3                       NaN       NaN
# 4                       NaN       NaN
# ...                     ...       ...
# 1440                    NaN       NaN
# 1441                    NaN       NaN
# 1442                    NaN       NaN
# 1443                      ?       NaN
# 1444                    NaN       NaN
#
# [1445 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

rental_units = np.array(sorted(df['RentUnits'], reverse=True))
plt.title('Numbers of rental units')
plt.plot(rental_units)

# %%
plt.title('Numbers of rental units no more than 16')
plt.plot(rental_units[rental_units<=16])
k=10
plt.axhline(k, color='r')

# %%
df_non_comm = df[df['RentUnits']<=k]
df_non_comm = df_non_comm[df_non_comm['RentUnits'] > 0]
df_non_comm
# Out:
#      Unnamed: 0.1 Unnamed: 0             Project Name  Neighborhood Zip Code  \
# 0              10         10       Alleyne (VUP) CDFI       Roxbury     2121
# 1              18         18            Andrade (VUP)    Dorchester     2122
# 2              19         19       Andrew Square Apts  South Boston     2127
# 3              41         41             Bailey (VUP)       Roxbury     2121
# 4              45         45           Baptista (VUP)    Dorchester     2125
# ..            ...        ...                      ...           ...      ...
# 398          1434       1434  xxxxx Clarkson St (REO)    Dorchester     2125
# 399          1437       1437     xxxxxx Washington St    Dorchester     2124
# 400          1439       1439    xxxxxxx Blue Hill Ave       Roxbury     2119
# 401          1440       1440   xxxxxxxx Blue Hill Ave       Roxbury     2119
# 402          1444       1444        Zebra Condominium     South End     2118
#
#      TtlProjUnits  RentUnits  OwnUnits  TtlMarket  MarketRent  MarketOwn  \
# 0               3          2         1        1.0         0.0        1.0
# 1               3          2         1        1.0         0.0        1.0
# 2               9          9         0        0.0         0.0        0.0
# 3               1          1         0        0.0         0.0        0.0
# 4               1          1         0        0.0         0.0        0.0
# ..            ...        ...       ...        ...         ...        ...
# 398             3          2         1        1.0         0.0        1.0
# 399             2          2         0        0.0         0.0        0.0
# 400            10         10         0        0.0         0.0        0.0
# 401             4          4         0        0.0         0.0        0.0
# 402            10          7         3        7.0         7.0        0.0
#
#      Total Income-Restricted  Income-Restricted Rental  \
# 0                          2                         2
# 1                          2                         2
# 2                          9                         9
# 3                          1                         1
# 4                          1                         1
# ..                       ...                       ...
# 398                        2                         2
# 399                        2                         2
# 400                       10                        10
# 401                        4                         4
# 402                        3                         0
#
#      Income-Restricted Ownership            Tenure Public/ Private  \
# 0                            0.0  Ownership/Rental         Private
# 1                            0.0  Ownership/Rental         Private
# 2                            0.0            Rental         Private
# 3                            0.0            Rental         Private
# 4                            0.0            Rental         Private
# ..                           ...               ...             ...
# 398                          0.0  Ownership/Rental         Private
# 399                          0.0            Rental         Private
# 400                          0.0            Rental          Public
# 401                          0.0            Rental         Private
# 402                          3.0  Ownership/Rental         Private
#
#     Includes Senior Units? Section 8
# 0                      NaN       NaN
# 1                      NaN       NaN
# 2                      NaN       NaN
# 3                      NaN       NaN
# 4                      NaN       NaN
# ..                     ...       ...
# 398                    NaN       NaN
# 399                    NaN       NaN
# 400                    NaN       NaN
# 401                    NaN       NaN
# 402                    NaN       NaN
#
# [403 rows x 18 columns]

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6))
neighborhoods = df_non_comm.groupby('Neighborhood')['Neighborhood'].count()
plt.title('Income-restricted Housing by Neighborhood')
plt.xticks(rotation=90)
plt.bar(neighborhoods.index, neighborhoods)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# Preprocessing income restricted non commercial

# %%
df_non_comm.to_csv('../data/income-restricted-non-commercial.csv')

# %%
df = pd.read_csv('../data/income-restricted-non-commercial.csv', dtype={'Zip Code':str})
df
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0             Project Name  \
# 0               0            10          10       Alleyne (VUP) CDFI
# 1               1            18          18            Andrade (VUP)
# 2               2            19          19       Andrew Square Apts
# 3               3            41          41             Bailey (VUP)
# 4               4            45          45           Baptista (VUP)
# ..            ...           ...         ...                      ...
# 398           398          1434        1434  xxxxx Clarkson St (REO)
# 399           399          1437        1437     xxxxxx Washington St
# 400           400          1439        1439    xxxxxxx Blue Hill Ave
# 401           401          1440        1440   xxxxxxxx Blue Hill Ave
# 402           402          1444        1444        Zebra Condominium
#
#      Neighborhood Zip Code  TtlProjUnits  RentUnits  OwnUnits  TtlMarket  \
# 0         Roxbury     2121             3          2         1        1.0
# 1      Dorchester     2122             3          2         1        1.0
# 2    South Boston     2127             9          9         0        0.0
# 3         Roxbury     2121             1          1         0        0.0
# 4      Dorchester     2125             1          1         0        0.0
# ..            ...      ...           ...        ...       ...        ...
# 398    Dorchester     2125             3          2         1        1.0
# 399    Dorchester     2124             2          2         0        0.0
# 400       Roxbury     2119            10         10         0        0.0
# 401       Roxbury     2119             4          4         0        0.0
# 402     South End     2118            10          7         3        7.0
#
#      MarketRent  MarketOwn  Total Income-Restricted  Income-Restricted Rental  \
# 0           0.0        1.0                        2                         2
# 1           0.0        1.0                        2                         2
# 2           0.0        0.0                        9                         9
# 3           0.0        0.0                        1                         1
# 4           0.0        0.0                        1                         1
# ..          ...        ...                      ...                       ...
# 398         0.0        1.0                        2                         2
# 399         0.0        0.0                        2                         2
# 400         0.0        0.0                       10                        10
# 401         0.0        0.0                        4                         4
# 402         7.0        0.0                        3                         0
#
#      Income-Restricted Ownership            Tenure Public/ Private  \
# 0                            0.0  Ownership/Rental         Private
# 1                            0.0  Ownership/Rental         Private
# 2                            0.0            Rental         Private
# 3                            0.0            Rental         Private
# 4                            0.0            Rental         Private
# ..                           ...               ...             ...
# 398                          0.0  Ownership/Rental         Private
# 399                          0.0            Rental         Private
# 400                          0.0            Rental          Public
# 401                          0.0            Rental         Private
# 402                          3.0  Ownership/Rental         Private
#
#     Includes Senior Units? Section 8
# 0                      NaN       NaN
# 1                      NaN       NaN
# 2                      NaN       NaN
# 3                      NaN       NaN
# 4                      NaN       NaN
# ..                     ...       ...
# 398                    NaN       NaN
# 399                    NaN       NaN
# 400                    NaN       NaN
# 401                    NaN       NaN
# 402                    NaN       NaN
#
# [403 rows x 19 columns]

# %%
import pandas as pd
import time
from functools import reduce
from geopy.geocoders import Nominatim

# %%
# setup geopy
geolocator = Nominatim(user_agent="preprocessing_noncomm")

# %%
def find_coordinates(df_row):
    addr = df_row['Unnamed: 0']+' '+ df_row['Project Name']+ ' '+df_row['Zip Code']
    
    time.sleep(0.1)
    try:
        location = geolocator.geocode(addr)
    except Exception as e:
        print("Error", e, "while getting", addr)
        return (pd.NA, pd.NA)
    
    if location == None:
        print("No location for", addr)
        return (pd.NA, pd.NA)
    else:
        print("Found location for", addr)
        return (location.latitude, location.longitude)

def fix_zip(zip):
    if len(zip) == 4:
        return '0' + zip
    else:
        return zip

# %%
# add coordinates to main dataset using geopy
df = pd.read_csv('../data/income-restricted-non-commercial.csv')
df['Unnamed: 0'] = df['Unnamed: 0'].astype(str)
df['Zip Code'] = df['Zip Code'].astype(str).apply(fix_zip)
df['coordinates'] = df.apply(find_coordinates, axis=1)
df.to_csv('../data/preprocessed_noncomm.csv')
# Out:
# No location for 10 Alleyne (VUP) CDFI 02121
# No location for 18 Andrade (VUP) 02122
# No location for 1324 x Tonawanda St (Johnson VUP) 02124
# No location for 1325 x Topliff St (REO) 02122
# No location for 1326 x Tremlett Street 02124
# No location for 1327 x Tremont 02118
# Found location for 1328 x Tremont St 02118
# No location for 1337 x W Park St (AOP) 02124
# No location for 1339 x W Second St 02127
# No location for 1340 x Walk Hill St (Johnson VUP) 02126
# No location for 1344 x Warren Street (1-4) 02119
# No location for 1345 x Warren Supportive Housing Phase 1 - Acquisition 02121
# No location for 1352 x Washington St Lodging 02124
# No location for 1355 x Waverly Street 02119
# No location for 1356 x Wayland St. Dorchester - COB 02125
# No location for 1357 x Wellesley Park, #1 02124
# No location for 1358 x Wenhan St (RDP) 02130
# No location for 1359 x Wentworth St (BuildHome) 02124
# No location for 1368 x Westminster (AOP) 02136
# No location for 1369 x Westmore Rd (BuildHome) 02126
# No location for 1370 x Wheatland Avenue 02124
# No location for 1371 x Wildwood Street 02124
# No location for 1373 x Winston Rd 02126
# Found location for 1375 x Woodbine Street 02119
# No location for 1376 x Woodrow Ave (James VUP) 02124
# No location for 1377 x Woodville 02119
# No location for 1379 x Wordsworth St (AOP) 02128
# No location for 1380 x x Harrishof St 02121
# No location for 1381 x Zeigler Street 02119
# No location for 1384 xx Blue Hill Ave 02119
# No location for 1385 xx Bowdoin St 02124
# No location for 1386 xx Chaucer St (AOP) 02128
# No location for 1387 xx Chelsea St (AOP) 02128
# No location for 1390 xx Dorchester Ave 02124
# Found location for 1393 xx Everett St 02128
# No location for 1394 xx Gladstone St (AOP) 02128
# No location for 1396 xx Huckins St 02119
# No location for 1398 xx Lexington St (1-4 Program) 02128
# No location for 1399 xx Magnolia St 02125
# Found location for 1400 xx Marion St 02128
# Error HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1403+xx+Maywood+Street+02119&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")) while getting 1403 xx Maywood Street 02119
# No location for 1404 xx Nelson Street 02124
# Found location for 1406 xx River Street 02136
# No location for 1407 xx Saratoga St (AOP) 02128
# No location for 1412 xx Wentworth St (BuildHome) 02124
# No location for 1416 xxx Blue Hill Ave 02119
# No location for 1417 xxx Blue Hill Avenue 02121
# No location for 1419 xxx Clarkson St (REO) 02125
# No location for 1421 xxx Marion St 02128
# No location for 1429 xxxx Clarkson St (REO) 02125
# No location for 1430 xxxx Saratoga Street 02128
# No location for 1431 xxxx Washington St 02130
# No location for 1433 xxxxx Blue Hill Ave 02121
# No location for 1434 xxxxx Clarkson St (REO) 02125
# No location for 1437 xxxxxx Washington St 02124
# No location for 1439 xxxxxxx Blue Hill Ave 02119
# No location for 1440 xxxxxxxx Blue Hill Ave 02119
# No location for 1444 Zebra Condominium 02118

# %%
# import all the libraries
import pandas as pd
import folium
from folium.plugins import HeatMap
import matplotlib.pyplot as plt
# read in dataset
noncomm_df = pd.read_csv('../data/preprocessed_noncomm.csv')

# %%
# plot a bar chart by zip code
fig, ax = plt.subplots(figsize=(20, 5))

zips = noncomm_df['Zip Code'].astype(str).groupby(noncomm_df['Zip Code'].astype(str)).count()
labels = [fix_zip(z) for z in zips.keys()]

ax.bar(labels, zips)
ax.set_ylabel("Number of total properties")
ax.set_title("All housing by ZIP code")

plt.show()

# %%
# clean up the dataset to plot coordinates
noncomm_df = noncomm_df.replace(to_replace=['\(', '\)'], value="", regex=True)
noncomm_df = noncomm_df[noncomm_df["coordinates"].str.contains('<NA>') == False]
noncomm_df[['Latitude', 'Longitude']] = noncomm_df["coordinates"].str.split(",", expand=True).astype(float)

# plot the map using latitude and longitude
map = folium.Map(location=[noncomm_df.iloc[0].Latitude, noncomm_df.iloc[0].Longitude])
for i in range(0,len(noncomm_df)):
    folium.CircleMarker(
      location=[noncomm_df.iloc[i]['Latitude'], noncomm_df.iloc[i]['Longitude']], radius=2,
      color = 'blue'
   ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa5c3b2c8e639d94c84b59bb5fe3eb4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa5c3b2c8e639d94c84b59bb5fe3eb4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_aa5c3b2c8e639d94c84b59bb5fe3eb4c = L.map(
#                 &quot;map_aa5c3b2c8e639d94c84b59bb5fe3eb4c&quot;,
#                 {
#                     center: [35.2802289, -81.5469111],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c077b7a215e7830efef69110b042fb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_c4b8723e092b85b8827ba4677aa02646 = L.circleMarker(
#                 [35.2802289, -81.5469111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_53de755a19f9ef58901c0b8d76b83a1a = L.circleMarker(
#                 [43.18079879166667, -89.22650504166667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_d33308eebac00e18660e209f251f4340 = L.circleMarker(
#                 [42.207609149999996, -71.12121473225],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_9497a37a5120dc464533c019e535e1f0 = L.circleMarker(
#                 [42.311363, -71.081148],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_fdd17dace5e5032c70317f02ee5a50e1 = L.circleMarker(
#                 [38.7364948, -90.6513202],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_c732cbd0bcafc376b58d2169083c9473 = L.circleMarker(
#                 [42.2934019, -71.1199176],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aa5c3b2c8e639d94c84b59bb5fe3eb4c);
#
#
#             var circle_marker_569845c2f6d6411c1b72012adb67a098 = L.circleMarker(
#                 [52.4396754, -1.4668099],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&qu

# %%
noncomm_df = noncomm_df.replace(to_replace=['\(', '\)'], value="", regex=True)
noncomm_df[['Latitude', 'Longitude']] = noncomm_df["coordinates"].str.split(",", expand=True)
noncomm_df = noncomm_df[noncomm_df["Latitude"].str.contains("<NA>") == False]
noncomm_df['Latitude'] = noncomm_df['Latitude'].astype(float)
noncomm_df['Longitude'] = noncomm_df['Longitude'].astype(float)

# plot the map using latitude and longitude
map = folium.Map(location=[noncomm_df.iloc[0].Latitude, noncomm_df.iloc[0].Longitude])
for i in range(0,len(noncomm_df)):
    folium.CircleMarker(
      location=[noncomm_df.iloc[i]['Latitude'], noncomm_df.iloc[i]['Longitude']], radius=100,
      color = 'red'
   ).add_to(map)
map
